# %%
import bs4 
import html5lib
import requests
import warnings
from bs4 import BeautifulSoup
warnings.filterwarnings("ignore")
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
url = "https://www.indeed.com/jobs?q=full%20stack%20developer&start=40&vjk=af5f9cc566508940"
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, "html5lib")

# %%
divs = soup.select("li > div")

# %%
len(divs)
# Out:
# 18

# %%
divs2 = soup.findAll("div", {"class", "job_seen_beacon"})

# %%
job_role = []
for i in divs2:
    cont_list = []
    job_role.append((i.find('a', {"class", "jcs-JobTitle css-jspxzf eu4oa1w0"}).text).capitalize())

# %%
print(job_role)
# Out:
# ['Full stack engineer', 'Remote - up to $120k - full stack javascript developer', 'Sr. full stack developer', 'Full stack javascript developer', 'Full stack software developer', 'Web developer', 'Senior full stack web3 developer', 'Sr full stack python developer', 'Software developer, full stack - remote', 'Software engineer i - full stack', 'Software developer – full stack (remote / nationwide)', 'Full stack javascript developer us', 'Full stack developer', 'Full stack developer', 'Full-stack engineer']

# %%
divs_item_main = []
for i in range(10+1):
     divs_item = []
     url = "https://www.indeed.com/jobs?q=fullstack%20developer&start="+ str(i) +"0&vjk=31790a0c30c2d332"
     r = requests.get(url)
     soup = BeautifulSoup(r.content, "html5lib")
     divs2 = soup.select("li > div")
     for i in divs2:
          divs_item_main.append(i)

# %%
job_role1 = []
for i in divs_item_main:
    role = i.find("div", class_="job_seen_beacon")
    job_role1.append(role)

# %%
print(job_role1)
# Out:
# [<div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><style data-emotion="css 1xpvg2o">.css-1xpvg2o{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;padding-right:2.6rem;}html[dir=rtl] .css-1xpvg2o{padding-right:0;padding-left:2.6rem;}</style><div class="css-1xpvg2o e37uo190"><style data-emotion="css 1h4a4n5">.css-1h4a4n5{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;}</style><h2 class="jobT
# ...
